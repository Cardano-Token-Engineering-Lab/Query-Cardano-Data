# %%
import koios_python
import pandas as pd

kp_mainnet = koios_python.URLs(url="http://10.0.0.89:3000/api/v1/")

# %%
TOKEN_POLICY_ID = "6d06570ddd778ec7c0cca09d381eca194e90c8cffa7582879735dbde"  # Replace with actual policy ID
TOKEN_ASSET_NAME = "584552"  # Replace with actual asset name
TOKEN_DECIMALS = 1e-6

# %%
def get_asset_info(policy_id=TOKEN_POLICY_ID, asset_name=TOKEN_ASSET_NAME):
    asset_info = kp_mainnet.get_asset_info(policy_id, asset_name)
    return asset_info


asset_info = get_asset_info()
print(asset_info)
# Out:
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(2 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(3 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(4 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(5 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(6 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(7 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(8 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(9 times)
# Exception Decode: Payload too heavy....bad JSON returned. Expecting value: line 1 column 1 (char 0)
# Retrying one more time...(10 times)
# Reached limit of attempts
# None

# %%
def get_addresses(policy_id=TOKEN_POLICY_ID, asset_name=TOKEN_ASSET_NAME):
    holders = kp_mainnet.get_asset_addresses(policy_id,asset_name)
    holders = pd.DataFrame(holders)
    return holders

holders = get_addresses()
print(holders)
# Out:
#                                        payment_address  \
# 0    addr1q802g7ag4tptkcztjh0r90s9jtxu4gatnyvp0kaj2...
# 1    addr1q8045ng0d4pyc4ma6gaq5r0smfcuwd7gh7fmvp3e3...
# 2    addr1q804xt2rmwjpn050kk0vnkq6xm0rhr7qvgr4vdjc8...
# 3    addr1q80697rn629m4utyvggx53wtewtm94w5ru89gvmt6...
# 4    addr1q80etyvvfavazas3hsj99vtexe4v5y3h956zjgglx...
# ..                                                 ...
# 995  addr1qxhjnjf2t0yvp3jwyaen3ewn0764dsy422ym3qfde...
# 996  addr1qxhk5pf9auvm3pvvp92v6rjddju9wrrx5mt6we8we...
# 997  addr1qxhnzq6f6fmncwrd09y3hw0uk7l4carz5wy5klkqh...
# 998  addr1qxhqcfg58usm0ptm9j8qfxpm9qeal6a9e8m6f4zcc...
# 999  addr1qxhuay7ehg6zwzacyfdd07gm448pgp6jkvzyxw7d4...
#
#                                          stake_address      quantity
# 0    stake1uyl7xzp7aawytmcymp8yy54d036t5nnrme6rhp22...    2844128897
# 1    stake1u9dhf0538d4kxpkdl9sr5q6qhgxdue9ejf69n4f4...   15062500000
# 2    stake1u89z79k74k90k2yxmcvj5ca24z2qvuqnednlk2uu...    1004166666
# 3    stake1ux0587dur24x0fpd4shf7f85e2k8hnww23jgs684...   52847768402
# 4    stake1ux6z5hzra774lzzyadj9ewde636t8q43x297ze4c...  113836666666
# ..                                                 ...           ...
# 995  stake1u887yulqsfwzczxrqujmr0474vd8cffpmxn5lt7l...  225500250000
# 996  stake1u8092cmf36kvugk2nal3r25y3j0qmtfayd4ctvjy...   99963487684
# 997  stake1u9k5k39n6eghqcr3x34yv6ufmlfs3283uf3vdyr8...   41572500000
# 998  stake1uyvravn5zfkalsrayt0ghv9w0nelywpdt8d5htd5...    5255931617
# 999  stake1ux2jzz6jueemxjy27du7htt6hq0ahqyrc40qut64...   10041666666
#
# [1000 rows x 3 columns]
